# %% [markdown]
# # 📊 Model Değerlendirme ve Analiz
#
# Bu notebook, eğitilmiş modellerin detaylı analizini yapar.
#
# ## İçerik
# 1. **Model Performans Metrikleri**
# 2. **Confusion Matrix Analizi**
# 3. **ROC Eğrisi ve AUC**
# 4. **Karar Sınırı Görselleştirme**
# 5. **Hata Analizi**
# 6. **Model Karşılaştırması**
