# %% [markdown]
# # 🏋️‍♂️ İleri Seviye Model Eğitimi
#
# Bu notebook, farklı model mimarileri ve eğitim tekniklerini karşılaştırır.
#
# ## İçerik
# 1. **Farklı Aktivasyon Fonksiyonları**
# 2. **Model Mimari Karşılaştırması**
# 3. **Hiperparametre Optimizasyonu**
# 4. **Farklı Veri Setleri ile Deneyler**
# 5. **Model Performans Analizi**
